# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
from collections import OrderedDict

# %%
def _ensure_divisible(number, divisor, min_value=None):
    '''
    Ensure that 'number' can be 'divisor' divisible
    Reference from original tensorflow repo:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    '''
    if min_value is None:
        min_value = divisor
    new_num = max(min_value, int(number + divisor / 2) // divisor * divisor)
    if new_num < 0.9 * number:
        new_num += divisor
        
    return new_num

# %%
class H_sigmoid(nn.Module):
    '''
    hard sigmoid
    '''
    def __init__(self, inplace=True):
        super(H_sigmoid, self).__init__()
        self.inplace = inplace

    def forward(self, x):
        return F.relu6(x + 3, inplace=self.inplace) / 6

class H_swish(nn.Module):
    '''
    hard swish
    '''
    def __init__(self, inplace=True):
        super(H_swish, self).__init__()
        self.inplace = inplace

    def forward(self, x):
        return x * F.relu6(x + 3, inplace=self.inplace) / 6

# %%
class SEModule(nn.Module):
    def __init__(self, in_channels_num, reduction_ratio=4):
        super(SEModule, self).__init__()

        if in_channels_num % reduction_ratio != 0:  # in_channels_num // reduction_ratio
            raise ValueError('in_channels_num must be divisible by reduction_ratio(default = 4)')
        
        # Squeeze
        self.avg_pool = nn.AdaptiveAvgPool2d(1)

        # Excitation
        self.fc = nn.Sequential(
            # F.C ReLU
            nn.Linear(in_channels_num, in_channels_num // reduction_ratio, bias=False),  # 1x1xC -> 1x1xC/r
            nn.ReLU(inplace=True),

            # F.C hard
            nn.Linear(in_channels_num // reduction_ratio, in_channels_num, bias=False),  # 1x1xC/r -> 1x1xC
            H_sigmoid()
        )

    def forward(self, x):  # x : feature
        batch_size, channel_num, _, _ = x.size()
        y = self.avg_pool(x).view(batch_size, channel_num)
        y = self.fc(y).view(batch_size, channel_num, 1, 1)  # channel weights

        return x * y  # feature recallibration

# %%
class Bottleneck(nn.Module):

    def __init__(self, in_channels_num, exp_size, out_channels_num, kernel_size, stride, use_SE, NL, BN_momentum):
        '''
        use_SE: True or False -- use SE Module or not
        NL: Non-linearity, 'ReLU' or 'H Swish'
        in_channels_num : 입력 채널
        exp_size : 중간 단계에서 확장되는 채널 (MobileNetV2의 narrow->wide->narrow의 wide 부분)
        out_channels_num : 출력 채널 (<= exp_size)
        '''
        super(Bottleneck, self).__init__()

        assert stride in [1, 2]  # stride=1일 때만 skip-conn 가능

        NL = NL.upper()
        assert NL in ['RE', 'HS']

        use_HS = NL == 'HS'
        
        # Whether to use residual structure or not
        self.use_residual = (stride == 1 and in_channels_num == out_channels_num)
        
        # W.O expansion 
        if exp_size == in_channels_num:
            # Depthwise-Conv
            self.conv1 = nn.Sequential(
                nn.Conv2d(in_channels=in_channels_num, out_channels=exp_size, kernel_size=kernel_size, stride=stride, padding=(kernel_size-1)//2, groups=in_channels_num, bias=False),
                nn.BatchNorm2d(num_features=exp_size, momentum=BN_momentum),

                # SE Module
                SEModule(exp_size) if use_SE else nn.Sequential(),
                H_swish() if use_HS else nn.ReLU(inplace=True))
            
            # Linear Pointwise-Conv
            self.conv2 = nn.Sequential(
                nn.Conv2d(in_channels=exp_size, out_channels=out_channels_num, kernel_size=1, stride=1, padding=0, bias=False),
                #nn.BatchNorm2d(num_features=out_channels_num, momentum=BN_momentum)
                nn.Sequential(OrderedDict([('lastBN', nn.BatchNorm2d(num_features=out_channels_num))])) if self.use_residual else
                    nn.BatchNorm2d(num_features=out_channels_num, momentum=BN_momentum)
            )

        # With expansion    
        else:
            # Pointwise-Conv for expansion
            self.conv1 = nn.Sequential(
                # Pointwise-Conv for expansion
                nn.Conv2d(in_channels=in_channels_num, out_channels=exp_size, kernel_size=1, stride=1, padding=0, bias=False),
                nn.BatchNorm2d(num_features=exp_size, momentum=BN_momentum),
                H_swish() if use_HS else nn.ReLU(inplace=True))
            
            # Depthwise-Conv
            self.conv2 = nn.Sequential(
                # Depthwise Convolution
                nn.Conv2d(in_channels=exp_size, out_channels=exp_size, kernel_size=kernel_size, stride=stride, padding=(kernel_size-1)//2, groups=exp_size, bias=False),
                nn.BatchNorm2d(num_features=exp_size, momentum=BN_momentum),

                # SE Module
                SEModule(exp_size) if use_SE else nn.Sequential(),
                H_swish() if use_HS else nn.ReLU(inplace=True),

                # Linear Pointwise-Conv
                nn.Conv2d(in_channels=exp_size, out_channels=out_channels_num, kernel_size=1, stride=1, padding=0, bias=False),
                #nn.BatchNorm2d(num_features=out_channels_num, momentum=BN_momentum)
                nn.Sequential(OrderedDict([('lastBN', nn.BatchNorm2d(num_features=out_channels_num))])) if self.use_residual else
                    nn.BatchNorm2d(num_features=out_channels_num, momentum=BN_momentum)
            )

    def forward(self, x, expand=False):
        out1 = self.conv1(x)  # Depthwise-Conv with SE
        out = self.conv2(out1)  # Output
        
        if self.use_residual:
            out = out + x
        if expand:
            return out, out1
        else:
            return out

# %%
class MobileNetV3(nn.Module):
    '''
    
    '''
    def __init__(self, mode='small', classes_num=1000, input_size=224, width_multiplier=1.0, dropout=0.2, BN_momentum=0.1, zero_gamma=False):
        '''
        configs: setting of the model
        mode: type of the model, 'large' or 'small'
        '''
        super(MobileNetV3, self).__init__()

        mode = mode.lower()
        assert mode in ['large', 'small']
        s = 2
        if input_size == 32 or input_size == 56:
            # using cifar-10, cifar-100 or Tiny-ImageNet
            s = 1

        # Configuration of a MobileNetV3-Large Model
        if mode == 'large':
            # kernel_size, exp_size, out_channels_num, use_SE, NL, stride
            configs = [
                [3, 16, 16, False, 'RE', 1],
                [3, 64, 24, False, 'RE', s],
                [3, 72, 24, False, 'RE', 1],
                [5, 72, 40, True, 'RE', 2],
                [5, 120, 40, True, 'RE', 1],
                [5, 120, 40, True, 'RE', 1],
                [3, 240, 80, False, 'HS', 2],
                [3, 200, 80, False, 'HS', 1],
                [3, 184, 80, False, 'HS', 1],
                [3, 184, 80, False, 'HS', 1],
                [3, 480, 112, True, 'HS', 1],
                [3, 672, 112, True, 'HS', 1],
                [5, 672, 160, True, 'HS', 2],
                [5, 960, 160, True, 'HS', 1],
                [5, 960, 160, True, 'HS', 1]
            ]

        # Configuration of a MobileNetV3-Small Model    
        elif mode == 'small':
            # kernel_size, exp_size, out_channels_num, use_SE, NL, stride
            configs = [
                [3, 16, 16, True, 'RE', s],
                [3, 72, 24, False, 'RE', 2],
                [3, 88, 24, False, 'RE', 1],
                [5, 96, 40, True, 'HS', 2],
                [5, 240, 40, True, 'HS', 1],
                [5, 240, 40, True, 'HS', 1],
                [5, 120, 48, True, 'HS', 1],
                [5, 144, 48, True, 'HS', 1],
                [5, 288, 96, True, 'HS', 2],
                [5, 576, 96, True, 'HS', 1],
                [5, 576, 96, True, 'HS', 1]
            ]

        first_channels_num = 16
        last_channels_num = 1280 if mode == 'large' else 1024

        divisor = 8

        ## Feature extraction ##
        # Input layer
        input_channels_num = _ensure_divisible(first_channels_num * width_multiplier, divisor)
        last_channels_num = _ensure_divisible(last_channels_num * width_multiplier, divisor) if width_multiplier > 1 else last_channels_num

        feature_extraction_layers = []
        first_layer = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=input_channels_num, kernel_size=3, stride=s, padding=1, bias=False),
            nn.BatchNorm2d(num_features=input_channels_num, momentum=BN_momentum),
            H_swish()
        )
        feature_extraction_layers.append(first_layer)

        # Bottleneck layers
        for kernel_size, exp_size, out_channels_num, use_SE, NL, stride in configs:
            output_channels_num = _ensure_divisible(out_channels_num * width_multiplier, divisor)
            exp_size = _ensure_divisible(exp_size * width_multiplier, divisor)

            feature_extraction_layers.append(Bottleneck(input_channels_num, exp_size, output_channels_num, kernel_size, stride, use_SE, NL, BN_momentum))
            input_channels_num = output_channels_num
        
        # Last layer
        last_stage_channels_num = _ensure_divisible(exp_size * width_multiplier, divisor)
        last_stage_layer1 = nn.Sequential(
                nn.Conv2d(in_channels=input_channels_num, out_channels=last_stage_channels_num, kernel_size=1, stride=1, padding=0, bias=False),
                nn.BatchNorm2d(num_features=last_stage_channels_num, momentum=BN_momentum),
                H_swish()
            )
        feature_extraction_layers.append(last_stage_layer1)

        
        self.featureList = nn.ModuleList(feature_extraction_layers)

        # SE Module
        last_stage = []
        last_stage.append(nn.AdaptiveAvgPool2d(1))
        last_stage.append(nn.Conv2d(in_channels=last_stage_channels_num, out_channels=last_channels_num, kernel_size=1, stride=1, padding=0, bias=False))
        last_stage.append(H_swish())

        self.last_stage_layers = nn.Sequential(*last_stage)
        
        # Classification 
        self.classifier = nn.Sequential(
            nn.Dropout(p=dropout),
            nn.Linear(last_channels_num, classes_num)
        )

        # Initialize the weights
        self._initialize_weights(zero_gamma)

    def forward(self, x):
        for i in range(9):
            x = self.featureList[i](x)
        x = self.featureList[9](x)
        for i in range(10, len(self.featureList)):
            x = self.featureList[i](x)

        x = self.last_stage_layers(x)

        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        
        return x

    def _initialize_weights(self, zero_gamma):
        '''
        Initialize the weights
        '''
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, std=0.001)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
        if zero_gamma:
            for m in self.modules():
	            if hasattr(m, 'lastBN'):
	                nn.init.constant_(m.lastBN.weight, 0.0)

# %%
# !pip install torchsummaryX
# Out:
# Collecting torchsummaryX
#   Downloading torchsummaryX-1.3.0-py3-none-any.whl (3.6 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchsummaryX) (1.10.0+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchsummaryX) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torchsummaryX) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torchsummaryX) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torchsummaryX) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torchsummaryX) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchsummaryX) (3.10.0.2)
# Installing collected packages: torchsummaryX
# Successfully installed torchsummaryX-1.3.0

# %%
from torchsummaryX import summary

width_multiplier = 1

model_small = MobileNetV3(mode='small', classes_num=10, input_size=32, width_multiplier=width_multiplier)
model_small.eval()
summary(model_small, torch.zeros((1, 3, 224, 224)))
print('MobileNetV3-Small-%.2f cifar10-summaryX\n' % width_multiplier)
# Out:
# =================================================================================================================
#                                                          Kernel Shape  \
# Layer
# 0_featureList.0.Conv2d_0                                [3, 16, 3, 3]
# 1_featureList.0.BatchNorm2d_1                                    [16]
# 2_featureList.0.H_swish_2                                           -
# 3_featureList.1.conv1.Conv2d_0                          [1, 16, 3, 3]
# 4_featureList.1.conv1.BatchNorm2d_1                              [16]
# 5_featureList.1.conv1.2.AdaptiveAvgPool2d_avg_pool                  -
# 6_featureList.1.conv1.2.fc.Linear_0                           [16, 4]
# 7_featureList.1.conv1.2.fc.ReLU_1                                   -
# 8_featureList.1.conv1.2.fc.Linear_2                           [4, 16]
# 9_featureList.1.conv1.2.fc.H_sigmoid_3                              -
# 10_featureList.1.conv1.ReLU_3                                       -
# 11_featureList.1.conv2.Conv2d_0                        [16, 16, 1, 1]
# 12_featureList.1.conv2.1.BatchNorm2d_lastBN                      [16]
# 13_featureList.2.conv1.Conv2d_0                        [16, 72, 1, 1]
# 14_featureList.2.conv1.BatchNorm2d_1                             [72]
# 15_featureList.2.conv1.ReLU_2                                       -
# 16_featureList.2.conv2.Conv2d_0                         [1, 72, 3, 3]
# 17_featureList.2.conv2.BatchNorm2d_1                             [72]
# 18_featureList.2.conv2.Sequential_2                                 -
# 19_featureList.2.conv2.ReLU_3                                       -
# 20_featureList.2.conv2.Conv2d_4                        [72, 24, 1, 1]
# 21_featureList.2.conv2.BatchNorm2d_5                             [24]
# 22_featureList.3.conv1.Conv2d_0                        [24, 88, 1, 1]
# 23_featureList.3.conv1.BatchNorm2d_1                             [88]
# 24_featureList.3.conv1.ReLU_2                                       -
# 25_featureList.3.conv2.Conv2d_0                         [1, 88, 3, 3]
# 26_featureList.3.conv2.BatchNorm2d_1                             [88]
# 27_featureList.3.conv2.Sequential_2                                 -
# 28_featureList.3.conv2.ReLU_3                                       -
# 29_featureList.3.conv2.Conv2d_4                        [88, 24, 1, 1]
# 30_featureList.3.conv2.5.BatchNorm2d_lastBN                      [24]
# 31_featureList.4.conv1.Conv2d_0                        [24, 96, 1, 1]
# 32_featureList.4.conv1.BatchNorm2d_1                             [96]
# 33_featureList.4.conv1.H_swish_2                                    -
# 34_featureList.4.conv2.Conv2d_0                         [1, 96, 5, 5]
# 35_featureList.4.conv2.BatchNorm2d_1                             [96]
# 36_featureList.4.conv2.2.AdaptiveAvgPool2d_avg_...                  -
# 37_featureList.4.conv2.2.fc.Linear_0                         [96, 24]
# 38_featureList.4.conv2.2.fc.ReLU_1                                  -
# 39_featureList.4.conv2.2.fc.Linear_2                         [24, 96]
# 40_featureList.4.conv2.2.fc.H_sigmoid_3                             -
# 41_featureList.4.conv2.H_swish_3                                    -
# 42_featureList.4.conv2.Conv2d_4                        [96, 40, 1, 1]
# 43_featureList.4.conv2.BatchNorm2d_5                             [40]
# 44_featureList.5.conv1.Conv2d_0                       [40, 240, 1, 1]
# 45_featureList.5.conv1.BatchNorm2d_1                            [240]
# 46_featureList.5.conv1.H_swish_2                                    -
# 47_featureList.5.conv2.Conv2d_0                        [1, 240, 5, 5]
# 48_featureList.5.conv2.BatchNorm2d_1                            [240]
# 49_featureList.5.conv2.2.AdaptiveAvgPool2d_avg_...                  -
# 50_featureList.5.conv2.2.fc.Linear_0                        [240, 60]
# 51_featureList.5.conv2.2.fc.ReLU_1                                  -
# 52_featureList.5.conv2.2.fc.Linear_2                        [60, 240]
# 53_featureList.5.conv2.2.fc.H_sigmoid_3                             -
# 54_featureList.5.conv2.H_swish_3                                    -
# 55_featureList.5.conv2.Conv2d_4                       [240, 40, 1, 1]
# 56_featureList.5.conv2.5.BatchNorm2d_lastBN                      [40]
# 57_featureList.6.conv1.Conv2d_0                       [40, 240, 1, 1]
# 58_featureList.6.conv1.BatchNorm2d_1                            [240]
# 59_featureList.6.conv1.H_swish_2                                    -
# 60_featureList.6.conv2.Conv2d_0                        [1, 240, 5, 5]
# 61_featureList.6.conv2.BatchNorm2d_1                            [240]
# 62_featureList.6.conv2.2.AdaptiveAvgPool2d_avg_...                  -
# 63_featureList.6.conv2.2.fc.Linear_0                        [240, 60]
# 64_featureList.6.conv2.2.fc.ReLU_1                                  -
# 65_featureList.6.conv2.2.fc.Linear_2                        [60, 240]
# 66_featureList.6.conv2.2.fc.H_sigmoid_3                             -
# 67_featureList.6.conv2.H_swish_3                                    -
# 68_featureList.6.conv2.Conv2d_4                       [240, 40, 1, 1]
# 69_featureList.6.conv2.5.BatchNorm2d_lastBN                      [40]
# 70_featureList.7.conv1.Conv2d_0                       [40, 120, 1, 1]
# 71_featureList.7.conv1.BatchNorm2d_1                            [120]
# 72_featureList.7.conv1.H_swish_2                                    -
# 73_featureList.7.conv2.Conv2d_0                        [1, 120, 5, 5]
# 74_featureList.7.conv2.BatchNorm2d_1                            [120]
# 75_featureList.7.conv2.2.AdaptiveAvgPool2d_avg_...                  -
# 76_featureList.7.conv2.2.fc.Linear_0                        [120, 30]
# 77_featureList.7.conv2.2.fc.ReLU_1                                  -
# 78_featureList.7.conv2.2.fc.Linear_2                        [30, 120]
# 79_featureList.7.conv2.2.fc.H_sigmoid_3                             -
# 80_featureList.7.conv2.H_swish_3                                    -
# 81_featureList.7.conv2.Conv2d_4                       [120, 48, 1, 1]
# 82_featureList.7.conv2.BatchNorm2d_5                             [48]
# 83_featureList.8.conv1.Conv2d_0                       [48, 144, 1, 1]
# 84_featureList.8.conv1.BatchNorm2d_1                            [144]
# 85_featureList.8.conv1.H_swish_2                                    -
# 86_featureList.8.conv2.Conv2d_0                        [1, 144, 5, 5]
# 87_featureList.8.conv2.BatchNorm2d_1                            [144]
# 88_featureList.8.conv2.2.AdaptiveAvgPool2d_avg_...                  -
# 89_featureList.8.conv2.2.fc.Linear_0                        [144, 36]
# 90_featureList.8.conv2.2.fc.ReLU_1                                  -
# 91_featureList.8.conv2.2.fc.Linear_2                        [36, 144]
# 92_featureList.8.conv2.2.fc.H_sigmoid_3                             -
# 93_featureList.8.conv2.H_swish_3                                    -
# 94_featureList.8.conv2.Conv2d_4                       [144, 48, 1, 1]
# 95_featureList.8.conv2.5.BatchNorm2d_lastBN                      [48]
# 96_featureList.9.conv1.Conv2d_0                       [48, 288, 1, 1]
# 97_featureList.9.conv1.BatchNorm2d_1                            [288]
# 98_featureList.9.conv1.H_swish_2                                    -
# 99_featureList.9.conv2.Conv2d_0                        [1, 288, 5, 5]
# 100_featureList.9.conv2.BatchNorm2d_1                           [288]
# 101_featureList.9.conv2.2.AdaptiveAvgPool2d_avg...                  -
# 102_featureList.9.conv2.2.fc.Linear_0                       [288, 72]
# 103_featureList.9.conv2.2.fc.ReLU_1                                 -
# 104_featureList.9.conv2.2.fc.Linear_2                       [72, 288]
# 105_featureList.9.conv2.2.fc.H_sigmoid_3                            -
# 106_featureList.9.conv2.H_swish_3                                   -
# 107_featureList.9.conv2.Conv2d_4                      [288, 96, 1, 1]
# 108_featureList.9.conv2.BatchNorm2d_5                            [96]
# 109_featureList.10.conv1.Conv2d_0                     [96, 576, 1, 1]
# 110_featureList.10.conv1.BatchNorm2d_1                          [576]
# 111_featureList.10.conv1.H_swish_2                                  -
# 112_featureList.10.conv2.Conv2d_0                      [1, 576, 5, 5]
# 113_featureList.10.conv2.BatchNorm2d_1                          [576]
# 114_featureList.10.conv2.2.AdaptiveAvgPool2d_av...                  -
# 115_featureList.10.conv2.2.fc.Linear_0                     [576, 144]
# 116_featureList.10.conv2.2.fc.ReLU_1                                -
# 117_featureList.10.conv2.2.fc.Linear_2                     [144, 576]
# 118_featureList.10.conv2.2.fc.H_sigmoid_3                           -
# 119_featureList.10.conv2.H_swish_3                                  -
# 120_featureList.10.conv2.Conv2d_4                     [576, 96, 1, 1]
# 121_featureList.10.conv2.5.BatchNorm2d_lastBN                    [96]
# 122_featureList.11.conv1.Conv2d_0                     [96, 576, 1, 1]
# 123_featureList.11.conv1.BatchNorm2d_1                          [576]
# 124_featureList.11.conv1.H_swish_2                                  -
# 125_featureList.11.conv2.Conv2d_0                      [1, 576, 5, 5]
# 126_featureList.11.conv2.BatchNorm2d_1                          [576]
# 127_featureList.11.conv2.2.AdaptiveAvgPool2d_av...                  -
# 128_featureList.11.conv2.2.fc.Linear_0                     [576, 144]
# 129_featureList.11.conv2.2.fc.ReLU_1                                -
# 130_featureList.11.conv2.2.fc.Linear_2                     [144, 576]
# 131_featureList.11.conv2.2.fc.H_sigmoid_3                           -
# 132_featureList.11.conv2.H_swish_3                                  -
# 133_featureList.11.conv2.Conv2d_4                     [576, 96, 1, 1]
# 134_featureList.11.conv2.5.BatchNorm2d_lastBN                    [96]
# 135_featureList.12.Conv2d_0                           [96, 576, 1, 1]
# 136_featureList.12.BatchNorm2d_1                                [576]
# 137_featureList.12.H_swish_2                                        -
# 138_last_stage_layers.AdaptiveAvgPool2d_0                           -
# 139_last_stage_layers.Conv2d_1                      [576, 1024, 1, 1]
# 140_last_stage_layers.H_swish_2                                     -
# 141_classifier.Dropout_0                                            -
# 142_classifier.Linear_1                                    [1024, 10]
#
#                                                          Output Shape  \
# Layer
# 0_featureList.0.Conv2d_0                            [1, 16, 224, 224]
# 1_featureList.0.BatchNorm2d_1                       [1, 16, 224, 224]
# 2_featureList.0.H_swish_2                           [1, 16, 224, 224]
# 3_featureList.1.conv1.Conv2d_0                      [1, 16, 224, 224]
# 4_featureList.1.conv1.BatchNorm2d_1                 [1, 16, 224, 224]
# 5_featureList.1.conv1.2.AdaptiveAvgPool2d_avg_pool      [1, 16, 1, 1]
# 6_featureList.1.conv1.2.fc.Linear_0                            [1, 4]
# 7_featureList.1.conv1.2.fc.ReLU_1                              [1, 4]
# 8_featureList.1.conv1.2.fc.Linear_2                           [1, 16]
# 9_featureList.1.conv1.2.fc.H_sigmoid_3                        [1, 16]
# 10_featureList.1.conv1.ReLU_3                       [1, 16, 224, 224]
# 11_featureList.1.conv2.Conv2d_0                     [1, 16, 224, 224]
# 12_featureList.1.conv2.1.BatchNorm2d_lastBN         [1, 16, 224, 224]
# 13_featureList.2.conv1.Conv2d_0                     [1, 72, 224, 224]
# 14_featureList.2.conv1.BatchNorm2d_1                [1, 72, 224, 224]
# 15_featureList.2.conv1.ReLU_2                       [1, 72, 224, 224]
# 16_featureList.2.conv2.Conv2d_0                     [1, 72, 112, 112]
# 17_featureList.2.conv2.BatchNorm2d_1                [1, 72, 112, 112]
# 18_featureList.2.conv2.Sequential_2                 [1, 72, 112, 112]
# 19_featureList.2.conv2.ReLU_3                       [1, 72, 112, 112]
# 20_featureList.2.conv2.Conv2d_4                     [1, 24, 112, 112]
# 21_featureList.2.conv2.BatchNorm2d_5                [1, 24, 112, 112]
# 22_featureList.3.conv1.Conv2d_0                     [1, 88, 112, 112]
# 23_featureList.3.conv1.BatchNorm2d_1                [1, 88, 112, 112]
# 24_featureList.3.conv1.ReLU_2                       [1, 88, 112, 112]
# 25_featureList.3.conv2.Conv2d_0                     [1, 88, 112, 112]
# 26_featureList.3.conv2.BatchNorm2d_1                [1, 88, 112, 112]
# 27_featureList.3.conv2.Sequential_2                 [1, 88, 112, 112]
# 28_featureList.3.conv2.ReLU_3                       [1, 88, 112, 112]
# 29_featureList.3.conv2.Conv2d_4                     [1, 24, 112, 112]
# 30_featureList.3.conv2.5.BatchNorm2d_lastBN         [1, 24, 112, 112]
# 31_featureList.4.conv1.Conv2d_0                     [1, 96, 112, 112]
# 32_featureList.4.conv1.BatchNorm2d_1                [1, 96, 112, 112]
# 33_featureList.4.conv1.H_swish_2                    [1, 96, 112, 112]
# 34_featureList.4.conv2.Conv2d_0                       [1, 96, 56, 56]
# 35_featureList.4.conv2.BatchNorm2d_1                  [1, 96, 56, 56]
# 36_featureList.4.conv2.2.AdaptiveAvgPool2d_avg_...      [1, 96, 1, 1]
# 37_featureList.4.conv2.2.fc.Linear_0                          [1, 24]
# 38_featureList.4.conv2.2.fc.ReLU_1                            [1, 24]
# 39_featureList.4.conv2.2.fc.Linear_2                          [1, 96]
# 40_featureList.4.conv2.2.fc.H_sigmoid_3                       [1, 96]
# 41_featureList.4.conv2.H_swish_3                      [1, 96, 56, 56]
# 42_featureList.4.conv2.Conv2d_4                       [1, 40, 56, 56]
# 43_featureList.4.conv2.BatchNorm2d_5                  [1, 40, 56, 56]
# 44_featureList.5.conv1.Conv2d_0                      [1, 240, 56, 56]
# 45_featureList.5.conv1.BatchNorm2d_1                 [1, 240, 56, 56]
# 46_featureList.5.conv1.H_swish_2                     [1, 240, 56, 56]
# 47_featureList.5.conv2.Conv2d_0                      [1, 240, 56, 56]
# 48_featureList.5.conv2.BatchNorm2d_1                 [1, 240, 56, 56]
# 49_featureList.5.conv2.2.AdaptiveAvgPool2d_avg_...     [1, 240, 1, 1]
# 50_featureList.5.conv2.2.fc.Linear_0                          [1, 60]
# 51_featureList.5.conv2.2.fc.ReLU_1                            [1, 60]
# 52_featureList.5.conv2.2.fc.Linear_2                         [1, 240]
# 53_featureList.5.conv2.2.fc.H_sigmoid_3                      [1, 240]
# 54_featureList.5.conv2.H_swish_3                     [1, 240, 56, 56]
# 55_featureList.5.conv2.Conv2d_4                       [1, 40, 56, 56]
# 56_featureList.5.conv2.5.BatchNorm2d_lastBN           [1, 40, 56, 56]
# 57_featureList.6.conv1.Conv2d_0                      [1, 240, 56, 56]
# 58_featureList.6.conv1.BatchNorm2d_1                 [1, 240, 56, 56]
# 59_featureList.6.conv1.H_swish_2                     [1, 240, 56, 56]
# 60_featureList.6.conv2.Conv2d_0                      [1, 240, 56, 56]
# 61_featureList.6.conv2.BatchNorm2d_1                 [1, 240, 56, 56]
# 62_featureList.6.conv2.2.AdaptiveAvgPool2d_avg_...     [1, 240, 1, 1]
# 63_featureList.6.conv2.2.fc.Linear_0                          [1, 60]
# 64_featureList.6.conv2.2.fc.ReLU_1                            [1, 60]
# 65_featureList.6.conv2.2.fc.Linear_2                         [1, 240]
# 66_featureList.6.conv2.2.fc.H_sigmoid_3                      [1, 240]
# 67_featureList.6.conv2.H_swish_3                     [1, 240, 56, 56]
# 68_featureList.6.conv2.Conv2d_4                       [1, 40, 56, 56]
# 69_featureList.6.conv2.5.BatchNorm2d_lastBN           [1, 40, 56, 56]
# 70_featureList.7.conv1.Conv2d_0                      [1, 120, 56, 56]
# 71_featureList.7.conv1.BatchNorm2d_1                 [1, 120, 56, 56]
# 72_featureList.7.conv1.H_swish_2                     [1, 120, 56, 56]
# 73_featureList.7.conv2.Conv2d_0                      [1, 120, 56, 56]
# 74_featureList.7.conv2.BatchNorm2d_1                 [1, 120, 56, 56]
# 75_featureList.7.conv2.2.AdaptiveAvgPool2d_avg_...     [1, 120, 1, 1]
# 76_featureList.7.conv2.2.fc.Linear_0                          [1, 30]
# 77_featureList.7.conv2.2.fc.ReLU_1                            [1, 30]
# 78_featureList.7.conv2.2.fc.Linear_2                         [1, 120]
# 79_featureList.7.conv2.2.fc.H_sigmoid_3                      [1, 120]
# 80_featureList.7.conv2.H_swish_3                     [1, 120, 56, 56]
# 81_featureList.7.conv2.Conv2d_4                       [1, 48, 56, 56]
# 82_featureList.7.conv2.BatchNorm2d_5                  [1, 48, 56, 56]
# 83_featureList.8.conv1.Conv2d_0                      [1, 144, 56, 56]
# 84_featureList.8.conv1.BatchNorm2d_1                 [1, 144, 56, 56]
# 85_featureList.8.conv1.H_swish_2                     [1, 144, 56, 56]
# 86_featureList.8.conv2.Conv2d_0                      [1, 144, 56, 56]
# 87_featureList.8.conv2.BatchNorm2d_1                 [1, 144, 56, 56]
# 88_featureList.8.conv2.2.AdaptiveAvgPool2d_avg_...     [1, 144, 1, 1]
# 89_featureList.8.conv2.2.fc.Linear_0                          [1, 36]
# 90_featureList.8.conv2.2.fc.ReLU_1                            [1, 36]
# 91_featureList.8.conv2.2.fc.Linear_2                         [1, 144]
# 92_featureList.8.conv2.2.fc.H_sigmoid_3                      [1, 144]
# 93_featureList.8.conv2.H_swish_3                     [1, 144, 56, 56]
# 94_featureList.8.conv2.Conv2d_4                       [1, 48, 56, 56]
# 95_featureList.8.conv2.5.BatchNorm2d_lastBN           [1, 48, 56, 56]
# 96_featureList.9.conv1.Conv2d_0                      [1, 288, 56, 56]
# 97_featureList.9.conv1.BatchNorm2d_1                 [1, 288, 56, 56]
# 98_featureList.9.conv1.H_swish_2                     [1, 288, 56, 56]
# 99_featureList.9.conv2.Conv2d_0                      [1, 288, 28, 28]
# 100_featureList.9.conv2.BatchNorm2d_1                [1, 288, 28, 28]
# 101_featureList.9.conv2.2.AdaptiveAvgPool2d_avg...     [1, 288, 1, 1]
# 102_featureList.9.conv2.2.fc.Linear_0                         [1, 72]
# 103_featureList.9.conv2.2.fc.ReLU_1                           [1, 72]
# 104_featureList.9.conv2.2.fc.Linear_2                        [1, 288]
# 105_featureList.9.conv2.2.fc.H_sigmoid_3                     [1, 288]
# 106_featureList.9.conv2.H_swish_3                    [1, 288, 28, 28]
# 107_featureList.9.conv2.Conv2d_4                      [1, 96, 28, 28]
# 108_featureList.9.conv2.BatchNorm2d_5                 [1, 96, 28, 28]
# 109_featureList.10.conv1.Conv2d_0                    [1, 576, 28, 28]
# 110_featureList.10.conv1.BatchNorm2d_1               [1, 576, 28, 28]
# 111_featureList.10.conv1.H_swish_2                   [1, 576, 28, 28]
# 112_featureList.10.conv2.Conv2d_0                    [1, 576, 28, 28]
# 113_featureList.10.conv2.BatchNorm2d_1               [1, 576, 28, 28]
# 114_featureList.10.conv2.2.AdaptiveAvgPool2d_av...     [1, 576, 1, 1]
# 115_featureList.10.conv2.2.fc.Linear_0                       [1, 144]
# 116_featureList.10.conv2.2.fc.ReLU_1                         [1, 144]
# 117_featureList.10.conv2.2.fc.Linear_2                       [1, 576]
# 118_featureList.10.conv2.2.fc.H_sigmoid_3                    [1, 576]
# 119_featureList.10.conv2.H_swish_3                   [1, 576, 28, 28]
# 120_featureList.10.conv2.Conv2d_4                     [1, 96, 28, 28]
# 121_featureList.10.conv2.5.BatchNorm2d_lastBN         [1, 96, 28, 28]
# 122_featureList.11.conv1.Conv2d_0                    [1, 576, 28, 28]
# 123_featureList.11.conv1.BatchNorm2d_1               [1, 576, 28, 28]
# 124_featureList.11.conv1.H_swish_2                   [1, 576, 28, 28]
# 125_featureList.11.conv2.Conv2d_0                    [1, 576, 28, 28]
# 126_featureList.11.conv2.BatchNorm2d_1               [1, 576, 28, 28]
# 127_featureList.11.conv2.2.AdaptiveAvgPool2d_av...     [1, 576, 1, 1]
# 128_featureList.11.conv2.2.fc.Linear_0                       [1, 144]
# 129_featureList.11.conv2.2.fc.ReLU_1                         [1, 144]
# 130_featureList.11.conv2.2.fc.Linear_2                       [1, 576]
# 131_featureList.11.conv2.2.fc.H_sigmoid_3                    [1, 576]
# 132_featureList.11.conv2.H_swish_3                   [1, 576, 28, 28]
# 133_featureList.11.conv2.Conv2d_4                     [1, 96, 28, 28]
# 134_featureList.11.conv2.5.BatchNorm2d_lastBN         [1, 96, 28, 28]
# 135_featureList.12.Conv2d_0                          [1, 576, 28, 28]
# 136_featureList.12.BatchNorm2d_1                     [1, 576, 28, 28]
# 137_featureList.12.H_swish_2                         [1, 576, 28, 28]
# 138_last_stage_layers.AdaptiveAvgPool2d_0              [1, 576, 1, 1]
# 139_last_stage_layers.Conv2d_1                        [1, 1024, 1, 1]
# 140_last_stage_layers.H_swish_2                       [1, 1024, 1, 1]
# 141_classifier.Dropout_0                                    [1, 1024]
# 142_classifier.Linear_1                                       [1, 10]
#
#                                                       Params   Mult-Adds
# Layer
# 0_featureList.0.Conv2d_0                               432.0  21.676032M
# 1_featureList.0.BatchNorm2d_1                           32.0        16.0
# 2_featureList.0.H_swish_2                                  -           -
# 3_featureList.1.conv1.Conv2d_0                         144.0   7.225344M
# 4_featureList.1.conv1.BatchNorm2d_1                     32.0        16.0
# 5_featureList.1.conv1.2.AdaptiveAvgPool2d_avg_pool         -           -
# 6_featureList.1.conv1.2.fc.Linear_0                     64.0        64.0
# 7_featureList.1.conv1.2.fc.ReLU_1                          -           -
# 8_featureList.1.conv1.2.fc.Linear_2                     64.0        64.0
# 9_featureList.1.conv1.2.fc.H_sigmoid_3                     -           -
# 10_featureList.1.conv1.ReLU_3                              -           -
# 11_featureList.1.conv2.Conv2d_0                        256.0  12.845056M
# 12_featureList.1.conv2.1.BatchNorm2d_lastBN             32.0        16.0
# 13_featureList.2.conv1.Conv2d_0                       1.152k  57.802752M
# 14_featureList.2.conv1.BatchNorm2d_1                   144.0        72.0
# 15_featureList.2.conv1.ReLU_2                              -           -
# 16_featureList.2.conv2.Conv2d_0                        648.0   8.128512M
# 17_featureList.2.conv2.BatchNorm2d_1                   144.0        72.0
# 18_featureList.2.conv2.Sequential_2                        -           -
# 19_featureList.2.conv2.ReLU_3                              -           -
# 20_featureList.2.conv2.Conv2d_4                       1.728k  21.676032M
# 21_featureList.2.conv2.BatchNorm2d_5                    48.0        24.0
# 22_featureList.3.conv1.Conv2d_0                       2.112k  26.492928M
# 23_featureList.3.conv1.BatchNorm2d_1                   176.0        88.0
# 24_featureList.3.conv1.ReLU_2                              -           -
# 25_featureList.3.conv2.Conv2d_0                        792.0   9.934848M
# 26_featureList.3.conv2.BatchNorm2d_1                   176.0        88.0
# 27_featureList.3.conv2.Sequential_2                        -           -
# 28_featureList.3.conv2.ReLU_3                              -           -
# 29_featureList.3.conv2.Conv2d_4                       2.112k  26.492928M
# 30_featureList.3.conv2.5.BatchNorm2d_lastBN             48.0        24.0
# 31_featureList.4.conv1.Conv2d_0                       2.304k  28.901376M
# 32_featureList.4.conv1.BatchNorm2d_1                   192.0        96.0
# 33_featureList.4.conv1.H_swish_2                           -           -
# 34_featureList.4.conv2.Conv2d_0                         2.4k     7.5264M
# 35_featureList.4.conv2.BatchNorm2d_1                   192.0        96.0
# 36_featureList.4.conv2.2.AdaptiveAvgPool2d_avg_...         -           -
# 37_featureList.4.conv2.2.fc.Linear_0                  2.304k      2.304k
# 38_featureList.4.conv2.2.fc.ReLU_1                         -           -
# 39_featureList.4.conv2.2.fc.Linear_2                  2.304k      2.304k
# 40_featureList.4.conv2.2.fc.H_sigmoid_3                    -           -
# 41_featureList.4.conv2.H_swish_3                           -           -
# 42_featureList.4.conv2.Conv2d_4                        3.84k   12.04224M
# 43_featureList.4.conv2.BatchNorm2d_5                    80.0        40.0
# 44_featureList.5.conv1.Conv2d_0                         9.6k    30.1056M
# 45_featureList.5.conv1.BatchNorm2d_1                   480.0       240.0
# 46_featureList.5.conv1.H_swish_2                           -           -
# 47_featureList.5.conv2.Conv2d_0                         6.0k     18.816M
# 48_featureList.5.conv2.BatchNorm2d_1                   480.0       240.0
# 49_featureList.5.conv2.2.AdaptiveAvgPool2d_avg_...         -           -
# 50_featureList.5.conv2.2.fc.Linear_0                   14.4k       14.4k
# 51_featureList.5.conv2.2.fc.ReLU_1                         -           -
# 52_featureList.5.conv2.2.fc.Linear_2                   14.4k       14.4k
# 53_featureList.5.conv2.2.fc.H_sigmoid_3                    -           -
# 54_featureList.5.conv2.H_swish_3                           -           -
# 55_featureList.5.conv2.Conv2d_4                         9.6k    30.1056M
# 56_featureList.5.conv2.5.BatchNorm2d_lastBN             80.0        40.0
# 57_featureList.6.conv1.Conv2d_0                         9.6k    30.1056M
# 58_featureList.6.conv1.BatchNorm2d_1                   480.0       240.0
# 59_featureList.6.conv1.H_swish_2                           -           -
# 60_featureList.6.conv2.Conv2d_0                         6.0k     18.816M
# 61_featureList.6.conv2.BatchNorm2d_1                   480.0       240.0
# 62_featureList.6.conv2.2.AdaptiveAvgPool2d_avg_...         -           -
# 63_featureList.6.conv2.2.fc.Linear_0                   14.4k       14.4k
# 64_featureList.6.conv2.2.fc.ReLU_1                         -           -
# 65_featureList.6.conv2.2.fc.Linear_2                   14.4k       14.4k
# 66_featureList.6.conv2.2.fc.H_sigmoid_3                    -           -
# 67_featureList.6.conv2.H_swish_3                           -           -
# 68_featureList.6.conv2.Conv2d_4                         9.6k    30.1056M
# 69_featureList.6.conv2.5.BatchNorm2d_lastBN             80.0        40.0
# 70_featureList.7.conv1.Conv2d_0                         4.8k    15.0528M
# 71_featureList.7.conv1.BatchNorm2d_1                   240.0       120.0
# 72_featureList.7.conv1.H_swish_2                           -           -
# 73_featureList.7.conv2.Conv2d_0                         3.0k      9.408M
# 74_featureList.7.conv2.BatchNorm2d_1                   240.0       120.0
# 75_featureList.7.conv2.2.AdaptiveAvgPool2d_avg_...         -           -
# 76_featureList.7.conv2.2.fc.Linear_0                    3.6k        3.6k
# 77_featureList.7.conv2.2.fc.ReLU_1                         -           -
# 78_featureList.7.conv2.2.fc.Linear_2                    3.6k        3.6k
# 79_featureList.7.conv2.2.fc.H_sigmoid_3                    -           -
# 80_featureList.7.conv2.H_swish_3                           -           -
# 81_featureList.7.conv2.Conv2d_4                        5.76k   18.06336M
# 82_featureList.7.conv2.BatchNorm2d_5                    96.0        48.0
# 83_featureList.8.conv1.Conv2d_0                       6.912k  21.676032M
# 84_featureList.8.conv1.BatchNorm2d_1                   288.0       144.0
# 85_featureList.8.conv1.H_swish_2                           -           -
# 86_featureList.8.conv2.Conv2d_0                         3.6k    11.2896M
# 87_featureList.8.conv2.BatchNorm2d_1                   288.0       144.0
# 88_featureList.8.conv2.2.AdaptiveAvgPool2d_avg_...         -           -
# 89_featureList.8.conv2.2.fc.Linear_0                  5.184k      5.184k
# 90_featureList.8.conv2.2.fc.ReLU_1                         -           -
# 91_featureList.8.conv2.2.fc.Linear_2                  5.184k      5.184k
# 92_featureList.8.conv2.2.fc.H_sigmoid_3                    -           -
# 93_featureList.8.conv2.H_swish_3                           -           -
# 94_featureList.8.conv2.Conv2d_4                       6.912k  21.676032M
# 95_featureList.8.conv2.5.BatchNorm2d_lastBN             96.0        48.0
# 96_featureList.9.conv1.Conv2d_0                      13.824k  43.352064M
# 97_featureList.9.conv1.BatchNorm2d_1                   576.0       288.0
# 98_featureList.9.conv1.H_swish_2                           -           -
# 99_featureList.9.conv2.Conv2d_0                         7.2k     5.6448M
# 100_featureList.9.conv2.BatchNorm2d_1                  576.0       288.0
# 101_featureList.9.conv2.2.AdaptiveAvgPool2d_avg...         -           -
# 102_featureList.9.conv2.2.fc.Linear_0                20.736k     20.736k
# 103_featureList.9.conv2.2.fc.ReLU_1                        -           -
# 104_featureList.9.conv2.2.fc.Linear_2                20.736k     20.736k
# 105_featureList.9.conv2.2.fc.H_sigmoid_3                   -           -
# 106_featureList.9.conv2.H_swish_3                          -           -
# 107_featureList.9.conv2.Conv2d_4                     27.648k  21.676032M
# 108_featureList.9.conv2.BatchNorm2d_5                  192.0        96.0
# 109_featureList.10.conv1.Conv2d_0                    55.296k  43.352064M
# 110_featureList.10.conv1.BatchNorm2d_1                1.152k       576.0
# 111_featureList.10.conv1.H_swish_2                         -           -
# 112_featureList.10.conv2.Conv2d_0                      14.4k    11.2896M
# 113_featureList.10.conv2.BatchNorm2d_1                1.152k       576.0
# 114_featureList.10.conv2.2.AdaptiveAvgPool2d_av...         -           -
# 115_featureList.10.conv2.2.fc.Linear_0               82.944k     82.944k
# 116_featureList.10.conv2.2.fc.ReLU_1                       -           -
# 117_featureList.10.conv2.2.fc.Linear_2               82.944k     82.944k
# 118_featureList.10.conv2.2.fc.H_sigmoid_3                  -           -
# 119_featureList.10.conv2.H_swish_3                         -           -
# 120_featureList.10.conv2.Conv2d_4                    55.296k  43.352064M
# 121_featureList.10.conv2.5.BatchNorm2d_lastBN          192.0        96.0
# 122_featureList.11.conv1.Conv2d_0                    55.296k  43.352064M
# 123_featureList.11.conv1.BatchNorm2d_1                1.152k       576.0
# 124_featureList.11.conv1.H_swish_2                         -           -
# 125_featureList.11.conv2.Conv2d_0                      14.4k    11.2896M
# 126_featureList.11.conv2.BatchNorm2d_1                1.152k       576.0
# 127_featureList.11.conv2.2.AdaptiveAvgPool2d_av...         -           -
# 128_featureList.11.conv2.2.fc.Linear_0               82.944k     82.944k
# 129_featureList.11.conv2.2.fc.ReLU_1                       -           -
# 130_featureList.11.conv2.2.fc.Linear_2               82.944k     82.944k
# 131_featureList.11.conv2.2.fc.H_sigmoid_3                  -           -
# 132_featureList.11.conv2.H_swish_3                         -           -
# 133_featureList.11.conv2.Conv2d_4                    55.296k  43.352064M
# 134_featureList.11.conv2.5.BatchNorm2d_lastBN          192.0        96.0
# 135_featureList.12.Conv2d_0                          55.296k  43.352064M
# 136_featureList.12.BatchNorm2d_1                      1.152k       576.0
# 137_featureList.12.H_swish_2                               -           -
# 138_last_stage_layers.AdaptiveAvgPool2d_0                  -           -
# 139_last_stage_layers.Conv2d_1                      589.824k    589.824k
# 140_last_stage_layers.H_swish_2                            -           -
# 141_classifier.Dropout_0                                   -           -
# 142_classifier.Linear_1                               10.25k      10.24k
# -----------------------------------------------------------------------------------------------------------------
#                           Totals
# Total params           1.518594M
# Trainable params       1.518594M
# Non-trainable params         0.0
# Mult-Adds             807.03636M
# =================================================================================================================
# MobileNetV3-Small-1.00 cifar10-summaryX
# /usr/local/lib/python3.7/dist-packages/torchsummaryX/torchsummaryX.py:101: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_sum = df.sum()

# %%
x = torch.randn([1, 3, 224, 224])
summary(model_small, x)
